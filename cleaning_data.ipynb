# %% [markdown]
# # Exploring Data

# %% [raw]
# import pandas as pd
# import numpy as np
# matplotlib inline

# %%
import pandas as pd
import numpy as np


jan_df = pd.read_parquet('data/yellow2025.parquet')
df = pd.concat([jan_df])
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60         1.0                  N           229           237
# 1           0.50         1.0                  N           236           237
# 2           0.60         1.0                  N           141           141
# 3           0.52         1.0                  N           244           244
# 4           0.66         1.0                  N           244           116
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.shape
# Out:
# (3475226, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3475226 entries, 0 to 3475225
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
#  19  cbd_congestion_fee     float64
# ...

# %%
df.isnull().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          540149
# trip_distance                 0
# RatecodeID               540149
# store_and_fwd_flag       540149
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge     540149
# Airport_fee              540149
# cbd_congestion_fee            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee'],
#       dtype='object')

# %%
df = df[['tpep_pickup_datetime', 'tpep_dropoff_datetime','passenger_count', 'trip_distance','RatecodeID','PULocationID', 'DOLocationID',
         'payment_type','total_amount']]
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0           1.60
# 1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0           0.50
# 2  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0           0.60
# 3  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0           0.52
# 4  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0           0.66
#
#    RatecodeID  PULocationID  DOLocationID  payment_type  total_amount
# 0         1.0           229           237             1         18.00
# 1         1.0           236           237             1         12.12
# 2         1.0           141           141             1         12.10
# 3         1.0           244           244             2          9.70
# 4         1.0           244           116             2          8.30

# %%
df.hist(figsize=(20,10),bins=60)
# Out:
# array([[<Axes: title={'center': 'tpep_pickup_datetime'}>,
#         <Axes: title={'center': 'tpep_dropoff_datetime'}>,
#         <Axes: title={'center': 'passenger_count'}>],
#        [<Axes: title={'center': 'trip_distance'}>,
#         <Axes: title={'center': 'RatecodeID'}>,
#         <Axes: title={'center': 'PULocationID'}>],
#        [<Axes: title={'center': 'DOLocationID'}>,
#         <Axes: title={'center': 'payment_type'}>,
#         <Axes: title={'center': 'total_amount'}>]], dtype=object)

# %%
df['RatecodeID'].value_counts()
# Out:
# RatecodeID
# 1.0     2756472
# 2.0       94420
# 99.0      41963
# 5.0       26501
# 3.0        8622
# 4.0        7092
# 6.0           7
# Name: count, dtype: int64

# %%
df.reset_index().plot(kind='scatter', y='total_amount', x ='index', figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
df[df['total_amount']<1000].reset_index().plot(kind='scatter', y = 'total_amount', x = 'index', figsize=(20,10))
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
df[df['total_amount']<0].reset_index().plot(kind='scatter', y = 'total_amount', x = 'index', figsize=(20,10))
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
df[df['total_amount']<0].head()
# Out:
#     tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 17   2025-01-01 00:01:41   2025-01-01 00:07:14              1.0
# 22   2025-01-01 00:55:54   2025-01-01 01:00:38              1.0
# 104  2025-01-01 00:56:12   2025-01-01 01:15:00              1.0
# 149  2025-01-01 00:55:53   2025-01-01 01:06:49              1.0
# 202  2025-01-01 00:29:35   2025-01-01 00:36:02              1.0
#
#      trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 17            0.71         1.0            79           107             2
# 22            0.69         1.0           137           233             4
# 104           0.97         1.0           161           170             4
# 149           1.42         1.0            79            45             2
# 202           0.60         1.0            79           148             4
#
#      total_amount
# 17          -8.54
# 22         -11.50
# 104        -21.30
# 149        -17.10
# 202        -12.20

# %%
df[df['total_amount']<0]['payment_type'].value_counts()
# Out:
# payment_type
# 4    37410
# 2    14111
# 3     8080
# 0     3421
# 1       15
# Name: count, dtype: int64

# %%
df[df['total_amount']==0].head()
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 10261         2  2025-01-01 01:30:13   2025-01-01 01:30:31              1.0
# 18189         1  2025-01-01 03:57:21   2025-01-01 04:02:26              1.0
# 19155         1  2025-01-01 03:27:25   2025-01-01 03:43:43              1.0
# 21300         2  2025-01-01 04:03:25   2025-01-01 04:11:42              2.0
# 21920         2  2025-01-01 04:24:55   2025-01-01 04:29:57              4.0
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 10261           0.00         1.0                  N           226
# 18189           0.40         1.0                  N           158
# 19155           3.50         1.0                  N           144
# 21300           4.69         1.0                  N           255
# 21920           1.72         1.0                  N             7
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
df[df['total_amount']==0]['payment_type'].value_counts()
# Out:
# payment_type
# 4    238
# 3    155
# 1     78
# 0     47
# 2     40
# 5      1
# Name: count, dtype: int64

# %%
df.reset_index().plot(kind='scatter',y='total_amount',x='index',figsize=(20,10))
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
df[df['total_amount']>200].shape
# Out:
# (1913, 20)

# %%
df['total_amount'].mean()
# Out:
# 25.61129169728817

# %% [markdown]
# # Cleaning Data

# %%
df_filtered = df[(df['total_amount']>=0)&(df['total_amount']<200)]

# %%
df_filtered.shape
# Out:
# (3410271, 20)

# %%
df_filtered.isna().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          536722
# trip_distance                 0
# RatecodeID               536722
# store_and_fwd_flag       536722
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge     536722
# Airport_fee              536722
# cbd_congestion_fee            0
# dtype: int64

# %%
df_filtered.isna()
# Out:
#          VendorID  tpep_pickup_datetime  tpep_dropoff_datetime  \
# 0           False                 False                  False
# 1           False                 False                  False
# 2           False                 False                  False
# 3           False                 False                  False
# 4           False                 False                  False
# ...           ...                   ...                    ...
# 3475221     False                 False                  False
# 3475222     False                 False                  False
# 3475223     False                 False                  False
# 3475224     False                 False                  False
# 3475225     False                 False                  False
#
#          passenger_count  trip_distance  RatecodeID  store_and_fwd_flag  \
# 0                  False          False       False               False
# ...
